# %% [markdown]
# # Import Library

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import tensorflow as tf

from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1. Data Import

# %% [markdown]
# ## Data Training

# %%
trainData = pd.read_csv('/content/drive/MyDrive/Skripsi/Dataset/Google_train_data.csv')
trainData.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2005-01-03  4.939940  5.096096  4.891391  5.072823   5.072823  633134232
# 1  2005-01-04  5.040040  5.078328  4.841842  4.867367   4.867367  549685764
# 2  2005-01-05  4.841091  4.927427  4.810561  4.842593   4.842593  329134536
# 3  2005-01-06  4.881882  4.902402  4.697698  4.718468   4.718468  415068516
# 4  2005-01-07  4.770771  4.861111  4.724224  4.851101   4.851101  386129484

# %%
trainData.tail()
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 3768  2019-12-20  68.154999  68.199997  67.536499  67.560997  67.560997
# 3769  2019-12-23  67.936501  68.092499  67.400002  67.531502  67.531502
# 3770  2019-12-24  67.510498  67.600502  67.208504  67.221497  67.221497
# 3771  2019-12-26  67.327499  68.160004  67.275497  68.123497  68.123497
# 3772  2019-12-27  68.199997  68.352501  67.650002  67.732002  67.732002
#
#         Volume
# 3768  50090000
# 3769  19936000
# 3770  13468000
# 3771  23662000
# 3772  23212000

# %% [markdown]
# ## Data Testing

# %%
testData = pd.read_csv('/content/drive/MyDrive/Skripsi/Dataset/Google_test_data.csv')
testData.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2020-01-02  67.420502  68.433998  67.324501  68.433998  68.433998  27278000
# 1  2020-01-03  67.400002  68.687500  67.365997  68.075996  68.075996  23408000
# 2  2020-01-06  67.581497  69.916000  67.550003  69.890503  69.890503  46768000
# 3  2020-01-07  70.023003  70.175003  69.578003  69.755501  69.755501  34330000
# 4  2020-01-08  69.740997  70.592499  69.631500  70.251999  70.251999  35314000

# %%
testData.tail()
# Out:
#            Date       Open        High        Low       Close   Adj Close  \
# 687  2022-09-23  99.629997   99.660004  97.470001   98.739998   98.739998
# 688  2022-09-26  98.099998   99.879997  97.800003   98.169998   98.169998
# 689  2022-09-27  99.430000  100.000000  96.870003   97.500000   97.500000
# 690  2022-09-28  97.650002  100.699997  97.110001  100.050003  100.050003
# 691  2022-09-29  98.639999   98.639999  95.959999   97.419998   97.419998
#
#        Volume
# 687  31602900
# 688  27072700
# 689  30072800
# 690  32466300
# 691  31047200

# %% [markdown]
# # 2. Pre-processing Data

# %% [markdown]
# ## Data Training

# %%
trainData["Date"] = pd.to_datetime(trainData['Date'])
trainData["Close"] = pd.to_numeric(trainData.Close,errors='coerce')

# %%
trainData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3773 entries, 0 to 3772
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3773 non-null   datetime64[ns]
#  1   Open       3773 non-null   float64
#  2   High       3773 non-null   float64
#  3   Low        3773 non-null   float64
#  4   Close      3773 non-null   float64
#  5   Adj Close  3773 non-null   float64
#  6   Volume     3773 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 206.5 KB

# %%
print(f"Dataframe data training contains stick prices between {trainData.Date.min()} {trainData.Date.max()}")
# Out:
# Dataframe data training contains stick prices between 2005-01-03 00:00:00 2019-12-27 00:00:00

# %%
trainData.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3773.000000  3773.000000  3773.000000  3773.000000  3773.000000
# mean     25.272311    25.495805    25.030308    25.267984    25.267984
# std      16.998138    17.129332    16.865559    17.004538    17.004538
# min       4.386887     4.464464     4.318569     4.379129     4.379129
# 25%      12.124625    12.272272    12.019019    12.132382    12.132382
# 50%      16.677677    16.838087    16.491993    16.694695    16.694695
# 75%      37.423500    37.695999    36.973499    37.441002    37.441002
# max      68.199997    68.352501    67.650002    68.123497    68.123497
#
#              Volume
# count  3.773000e+03
# mean   1.370129e+08
# std    1.533007e+08
# min    1.041200e+07
# 25%    3.768600e+07
# 50%    8.565426e+07
# 75%    1.735343e+08
# max    1.643023e+09

# %%
trainData.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
trainData["Close"] = pd.to_numeric(trainData.Close,errors='coerce')
trainData = trainData.dropna()
trainData = trainData.iloc[:,4:5].values

# %%
trainData.shape
# Out:
# (3773, 1)

# %% [markdown]
# ## Data Testing

# %%
testData["Date"] = pd.to_datetime(testData['Date'])
testData["Close"] = pd.to_numeric(testData.Close,errors='coerce')

# %%
testData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692 entries, 0 to 691
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       692 non-null    datetime64[ns]
#  1   Open       692 non-null    float64
#  2   High       692 non-null    float64
#  3   Low        692 non-null    float64
#  4   Close      692 non-null    float64
#  5   Adj Close  692 non-null    float64
#  6   Volume     692 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 38.0 KB

# %%
print(f"Dataframe data testing contains stick prices between {testData.Date.min()} {testData.Date.max()}")
# Out:
# Dataframe data testing contains stick prices between 2020-01-02 00:00:00 2022-09-29 00:00:00

# %%
testData.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  692.000000  692.000000  692.000000  692.000000  692.000000
# mean   105.096108  106.296826  103.873659  105.109794  105.109794
# std     27.563672   27.680639   27.313133   27.474310   27.474310
# min     52.818501   53.345501   50.443501   52.706501   52.706501
# 25%     76.292000   77.711498   75.521250   76.227625   76.227625
# 50%    108.999748  110.918999  107.260250  108.996498  108.996498
# 75%    130.948749  132.298496  127.991747  129.876373  129.876373
# max    151.250000  151.546494  148.899002  149.838501  149.838501
#
#              Volume
# count  6.920000e+02
# mean   3.539041e+07
# std    1.571323e+07
# min    9.312000e+06
# 25%    2.513400e+07
# 50%    3.158800e+07
# 75%    4.047900e+07
# max    1.232000e+08

# %%
testData.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
testData = testData.iloc[:,4:5]
y_test = testData.iloc[60:,0:].values

# %%
y_test.shape
# Out:
# (632, 1)

# %% [markdown]
# # 3. Feature Scaling

# %% [markdown]
# ## Data Training

# %%
sc = MinMaxScaler(feature_range=(0,1))
trainData = sc.fit_transform(trainData)
trainData.shape
# Out:
# (3773, 1)

# %% [markdown]
# ## Data Testing

# %%
inputClosing = testData.iloc[:,0:].values 
inputClosing_scaled = sc.fit_transform(inputClosing)
inputClosing_scaled.shape
# Out:
# (692, 1)

# %% [markdown]
# # 4. Training Data

# %% [markdown]
# ## Splitting Data

# %%
X_train = []
y_train = []

for i in range (60, len(trainData)): # 60 = timestep
    X_train.append(trainData[i-60:i,0]) 
    y_train.append(trainData[i,0])

X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train = np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1)) #adding the batch_size axis

# %%
print("X train shape : ", X_train.shape)
print("y train shape : ", y_train.shape)
# Out:
# X train shape :  (3713, 60, 1)
# y train shape :  (3713,)

# %%
X_test = []
length = len(testData)
timestep = 60

for i in range(timestep,length):  
    X_test.append(inputClosing_scaled[i-timestep:i,0])
    
X_test = np.array(X_test)
X_test = np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))

# %%
print("X test shape : ", X_test.shape)
print("y test shape : ", y_test.shape)
# Out:
# X test shape :  (632, 60, 1)
# y test shape :  (632, 1)

# %% [markdown]
# ## Build LSTM Model

# %%
model = Sequential()

model.add(LSTM(units=200, return_sequences = True, input_shape = (X_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units=200, activation = "relu", return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units=200, activation = "relu",return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units=200, activation = "linear", return_sequences = False))
model.add(Dropout(0.2))

model.add(Dense(units = 1))
model.compile(optimizer='adam', loss = "mean_squared_error")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 200)           161600
#
#  dropout (Dropout)           (None, 60, 200)           0
#
#  lstm_1 (LSTM)               (None, 60, 200)           320800
#
#  dropout_1 (Dropout)         (None, 60, 200)           0
#
#  lstm_2 (LSTM)               (None, 60, 200)           320800
#
#  dropout_2 (Dropout)         (None, 60, 200)           0
#
#  lstm_3 (LSTM)               (None, 200)               320800
#
#  dropout_3 (Dropout)         (None, 200)               0
#
#  dense (Dense)               (None, 1)                 201
#
# =================================================================
# Total params: 1,124,201
# Trainable params: 1,124,201
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Visualisasi Model

# %%
tf.keras.utils.plot_model(model, 
                          show_shapes = True, 
                          show_dtype = False, 
                          show_layer_names = True, 
                          expand_nested = True, 
                          show_layer_activations = True)

# %% [markdown]
# ## Fit Model

# %%
hist = model.fit(X_train, y_train, 
                 epochs = 10, 
                 batch_size = 200, 
                 verbose = 2, 
                 validation_data = (X_train, y_train))
# Out:
# Epoch 1/10
# 19/19 - 57s - loss: 0.0581 - val_loss: 0.0139 - 57s/epoch - 3s/step
# Epoch 2/10
# 19/19 - 49s - loss: 0.0075 - val_loss: 0.0018 - 49s/epoch - 3s/step
# Epoch 3/10
# 19/19 - 49s - loss: 0.0016 - val_loss: 5.5036e-04 - 49s/epoch - 3s/step
# Epoch 4/10
# 19/19 - 51s - loss: 0.0011 - val_loss: 4.6541e-04 - 51s/epoch - 3s/step
# Epoch 5/10
# 19/19 - 50s - loss: 0.0010 - val_loss: 4.3747e-04 - 50s/epoch - 3s/step
# Epoch 6/10
# 19/19 - 50s - loss: 9.7546e-04 - val_loss: 4.8380e-04 - 50s/epoch - 3s/step
# Epoch 7/10
# 19/19 - 50s - loss: 9.6266e-04 - val_loss: 4.4614e-04 - 50s/epoch - 3s/step
# Epoch 8/10
# 19/19 - 51s - loss: 9.9063e-04 - val_loss: 4.0421e-04 - 51s/epoch - 3s/step
# Epoch 9/10
# 19/19 - 49s - loss: 9.5621e-04 - val_loss: 4.0106e-04 - 49s/epoch - 3s/step
# Epoch 10/10
# 19/19 - 50s - loss: 9.2891e-04 - val_loss: 4.5361e-04 - 50s/epoch - 3s/step

# %% [markdown]
# ## Evaluation Model

# %%
model.metrics_names
# Out:
# ['loss']

# %%
score_training = model.evaluate(X_train, y_train, verbose = 1)
print('Training loss :', score_training)
# Out:
# 117/117 [==============================] - 22s 188ms/step - loss: 4.5361e-04
# Training loss : 0.00045360776130110025

# %%
score_testing = model.evaluate(X_test, y_test, verbose = 1)
print('Test loss :', score_testing)
# Out:
# 20/20 [==============================] - 5s 185ms/step - loss: 12341.9014
# Test loss : 12341.9013671875

# %% [markdown]
# ## Visualisasi Training Model Loss

# %%
plt.plot(hist.history['loss'])
plt.title('Training model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# ## Save Model LSTM

# %%
model.save("saved_model.h5")

# %% [markdown]
# # 5. Prediction Data

# %%
X_pred = model.predict(X_train)
X_pred.shape
# Out:
# 117/117 [==============================] - 23s 189ms/step
# (3713, 1)

# %%
y_pred = model.predict(X_test)
y_pred.shape
# Out:
# 20/20 [==============================] - 4s 186ms/step
# (632, 1)

# %% [markdown]
# ## Feature Scaling

# %%
X_pred = sc.inverse_transform(X_pred)

# %%
predicted_price = sc.inverse_transform(y_pred)

# %% [markdown]
# ## Visualisasi hasil prediksi dengan harga aktual

# %%
difference = predicted_price - y_test

# %%
Prediction = pd.DataFrame ({"nilai aktual" : y_test.flatten(), 
                            "nilai prediksi " : predicted_price.flatten(),
                            "Difference " : difference.flatten()})
Prediction
# Out:
#      nilai aktual  nilai prediksi   Difference
# 0       57.315498        59.964252     2.648754
# 1       58.097500        59.265141     1.167641
# 2       55.105000        58.661251     3.556251
# 3       55.851501        58.147839     2.296338
# 4       54.634998        57.717178     3.082180
# ..            ...              ...          ...
# 627     98.739998       108.683304     9.943306
# 628     98.169998       108.036766     9.866768
# 629     97.500000       107.368332     9.868332
# 630    100.050003       106.679924     6.629921
# 631     97.419998       105.981544     8.561546
#
# [632 rows x 3 columns]

# %%
plt.plot(difference, color = "blue", label = "Difference")
plt.title('Google stock price prediction difference')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.legend()
plt.show()

# %%
plt.plot(y_test, color = 'red', label = 'Actual Stock Price')
plt.plot(predicted_price, color = 'green', label = 'Predicted Stock Price')
plt.title('Google stock price prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# # 6. Result and Conclusion

# %% [markdown]
# ## RMSE ( Root Mean Squared Error )

# %%
import math
from sklearn.metrics import mean_squared_error

print("Train RMSE : ", math.sqrt(mean_squared_error(y_train, X_pred)))
print("Test RMSE : ", math.sqrt(mean_squared_error(y_test, predicted_price)))
# Out:
# Train RMSE :  87.73472589686304
# Test RMSE :  5.694711860891663

# %% [markdown]
# ## MSE ( Mean Squared Error )

# %%
# MSE Training
MSE_train = np.square(np.subtract(y_train, X_pred)).mean()
print("Train MSE : ", MSE_train)

# MSE Testing
MSE_test = np.square(np.subtract(y_test, predicted_price)).mean()
print("Testing MSE : ", MSE_test)
# Out:
# Train MSE :  7710.746576968337
# Testing MSE :  32.42974317858018

# %% [markdown]
# ## MAE ( Mean Absolute Error )

# %%
from sklearn.metrics import mean_absolute_error as mae

# MAE Training
mae_train = mae(y_train, X_pred)
print("MAE Training : " + str(mae_train))

# MAE Testing
mae_test = mae(y_test, predicted_price)
print("MAE Testing : " + str(mae_test))
# Out:
# MAE Training : 84.11078370574874
# MAE Testing : 4.660395093841553
